# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader, Dataset
import numpy as np
import os
from PIL import Image

# %%
import numpy as np
import PIL
print(f"NumPy version: {np.__version__}")
print(f"Pillow version: {PIL.__version__}")
# Out:
# NumPy version: 2.2.6
# Pillow version: 11.2.1

# %%
# Custom Dataset Class
class MaskDataset(Dataset):
    def __init__(self, mask_dir, no_mask_dir, transform=None):
        self.transform = transform
        self.data = []
        self.labels = []


        for folder, label in [(mask_dir, 1), (no_mask_dir, 0)]:
            for file in os.listdir(folder):
                img_path = os.path.join(folder, file)
                try:
                    img = Image.open(img_path).convert("RGB")
                    if self.transform:
                        img = self.transform(img)
                    self.data.append(img)
                    self.labels.append(label)
                except Exception as e:
                    print(f"Failed to load image {img_path}: {e}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# %%
# Define Data Transformations
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize for RGB
])


# Define Dataset Paths
mask_folder = "../data/with_mask_without_mask_classification/with_mask"
no_mask_folder = "../data/with_mask_without_mask_classification/without_mask"

# %%
# Load Dataset
dataset = MaskDataset(mask_folder, no_mask_folder, transform=transform)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# # Define CNN Model

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 1)
        self.dropout = nn.Dropout(0.5)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))
        x = x.view(x.shape[0], -1)  # Flatten
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.sigmoid(self.fc2(x))
        return x

# Initialize Model, Loss, and Optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN().to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Train the Model

# %%
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device).float().unsqueeze(1)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader):.4f}")
# Out:
# Epoch 1/10, Loss: 0.4025
# Epoch 2/10, Loss: 0.1840
# Epoch 3/10, Loss: 0.1519
# Epoch 4/10, Loss: 0.0971
# Epoch 5/10, Loss: 0.0764
# Epoch 6/10, Loss: 0.0829
# Epoch 7/10, Loss: 0.0603
# Epoch 8/10, Loss: 0.0493
# Epoch 9/10, Loss: 0.0347
# Epoch 10/10, Loss: 0.0275

# %% [markdown]
# # Evaluate the Model

# %%
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        predicted = (outputs > 0.5).float()
        total += labels.size(0)
        correct += (predicted == labels.unsqueeze(1)).sum().item()

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Test Accuracy: 0.97

# %%
from sklearn.model_selection import ParameterGrid
import torch.nn.functional as F

param_grid = {
    'lr': [0.001, 0.0005],
    'batch_size': [16, 32],
    'dropout': [0.3, 0.5],
    'activation': ['relu', 'leaky_relu'],
    'optimizer': ['adam', 'sgd']
}

best_accuracy = 0.0
best_params = {}

for params in ParameterGrid(param_grid):
    print(f"Testing parameters: {params}")

    # Define activation function
    def activation_fn(x):
        if params['activation'] == 'relu':
            return F.relu(x)
        elif params['activation'] == 'leaky_relu':
            return F.leaky_relu(x, negative_slope=0.01)

    # Update DataLoader
    train_loader = DataLoader(train_dataset, batch_size=params['batch_size'], shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=params['batch_size'], shuffle=False)

    # Define model with dynamic dropout and activation
    class TunedCNN(nn.Module):
        def __init__(self, dropout):
            super(TunedCNN, self).__init__()
            self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
            self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
            self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(2, 2)
            self.fc1 = nn.Linear(128 * 8 * 8, 128)
            self.fc2 = nn.Linear(128, 1)
            self.dropout = nn.Dropout(dropout)
            self.sigmoid = nn.Sigmoid()

        def forward(self, x):
            x = self.pool(activation_fn(self.conv1(x)))
            x = self.pool(activation_fn(self.conv2(x)))
            x = self.pool(activation_fn(self.conv3(x)))
            x = x.view(x.shape[0], -1)
            x = activation_fn(self.fc1(x))
            x = self.dropout(x)
            x = self.sigmoid(self.fc2(x))
            return x

    model = TunedCNN(params['dropout']).to(device)
    criterion = nn.BCELoss()

    # Select optimizer
    if params['optimizer'] == 'adam':
        optimizer = optim.Adam(model.parameters(), lr=params['lr'])
    elif params['optimizer'] == 'sgd':
        optimizer = optim.SGD(model.parameters(), lr=params['lr'], momentum=0.9)

    # Training loop (reduced epochs for tuning)
    for epoch in range(5):
        model.train()
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device).float().unsqueeze(1)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Evaluation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            predicted = (outputs > 0.5).float()
            total += labels.size(0)
            correct += (predicted == labels.unsqueeze(1)).sum().item()

    accuracy = correct / total
    print(f"Accuracy: {accuracy:.4f}")

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_params = params

print(f"\nBest Accuracy: {best_accuracy:.4f} with params: {best_params}")
# Out:
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9674
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.7862
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9710
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9529
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.8587
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9457
# Testing parameters: {'activation': 'relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9420
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9565
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9601
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9601
# Testing parameters: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9783
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.8551
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9746
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9819
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9746
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9710
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9457
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.3, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'adam'}
# Accuracy: 0.9638
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'sgd'}
# Accuracy: 0.7355
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'adam'}
# Accuracy: 0.9638
# Testing parameters: {'activation': 'leaky_relu', 'batch_size': 32, 'dropout': 0.5, 'lr': 0.0005, 'optimizer': 'sgd'}
# Accuracy: 0.7355
#
# Best Accuracy: 0.9819 with params: {'activation': 'leaky_relu', 'batch_size': 16, 'dropout': 0.5, 'lr': 0.001, 'optimizer': 'adam'}
